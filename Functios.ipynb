# %% [markdown]
# # Lecture #8
# <br>
# Defining and Calling Functions; Parameters and Return Values

# %% [markdown]
# ## 1. Defining and Calling Functions
#
# A **function** is a reusable block of code that performs a specific task. Functions help reduce code duplication, improve readability, and make programs easier to maintain.

# %% [markdown]
# ### Why Use Functions?
# - Break large programs into smaller manageable parts.
# - Avoid repeating the same code multiple times.
# - Improve code readability and organization.
# - Simplify debugging and maintenance.
# - Promote code reusability.

# %% [markdown]
# ### Basic Syntax
# ```python
#     def function_name():
#         # Function body
#         print("Hello World")
# ```

# %% [markdown]
# ### Calling a Function

# %%
def greet(): 
    print("Welcome to Python") 

greet()
# Out:
# Welcome to Python

# %% [markdown]
# ### Function Execution Flow
#
# 1. Function is defined using `def`.
# 2. Python stores the function in memory.
# 3. Function code does not execute until it is called.
# 4. When called, Python executes the statements inside the function.

# %% [markdown]
# # 2. Parameters and Arguments
#
# A **parameter** is a variable listed in the function definition.<br>
# An **argument** is the actual value passed to the function during the call.

# %% [markdown]
# ### Syntax
# ```python
# def function_name(parameter):
#     # code
#
# function_name(argument)
# ```

# %% [markdown]
# ### Example

# %%
def greet(name): 
    print("Hello", name) 
    
greet("Ali")
# Out:
# Hello Ali

# %% [markdown]
# - `name` → Parameter
# - `"Ali"` → Argument

# %% [markdown]
# # 3. Return Values
#
# A function can send a result back to the caller using the `return` statement.

# %% [markdown]
# ### Syntax
# ```python
# def function_name():
#     return value
# ```

# %% [markdown]
# ### Example

# %%
def add(): 
    return 10 + 20 

result = add() 
print(result)
# Out:
# 30

# %% [markdown]
# ### Why Return Values?
#
# - Store results in variables.
# - Use results in calculations.
# - Pass results to other functions.

# %% [markdown]
# # Functions with Different Data Types

# %% [markdown]
# ## A. Integer Parameters and Return Values
#
# ### Example 1: Addition

# %%
def add(a, b): 
    return a + b 

result = add(5, 3) 
print(result)
# Out:
# 8

# %% [markdown]
# ### Example 2: Multiplication

# %%
def multiply(x, y): 
    return x * y 

print(multiply(4, 6))
# Out:
# 24

# %% [markdown]
# ## B. Float Parameters and Return Values
#
# ### Example 1: Calculate Area of Circle

# %%
def area_circle(radius): 
    return 3.14159 * radius * radius 

print(area_circle(2.5))
# Out:
# 19.6349375

# %% [markdown]
# ### Example 2: Average

# %%
def average(a, b): 
    return (a + b) / 2 

print(average(4.5, 7.5))
# Out:
# 6.0

# %% [markdown]
# ## C. String Parameters and Return Values
# ### Example 1: Greeting

# %%
def greet(name): 
    return "Hello " + name 

print(greet("Umer"))
# Out:
# Hello Umer

# %% [markdown]
# ### Example 2: Convert to Uppercase

# %%
def to_upper(text): 
    return text.upper() 

print(to_upper("python"))
# Out:
# PYTHON

# %% [markdown]
# ## D. Boolean Parameters and Return Values
# ### Example 1: Voting Eligibility

# %%
def can_vote(age): 
    return age >= 18 

print(can_vote(20)) 
print(can_vote(15))
# Out:
# True
# False

# %% [markdown]
# ### Example 2: Check Positive Number

# %%
def is_positive(num): 
    return num > 0 

print(is_positive(10)) 
print(is_positive(-5))
# Out:
# True
# False

# %% [markdown]
# ## E. List Parameters and Return Values
#
# ### Example 1: Sum of List

# %%
def total(numbers): 
    return sum(numbers) 

print(total([10, 20, 30]))
# Out:
# 60

# %% [markdown]
# ### Example 2: Return Squared List

# %%
def square_list(nums):
    result = []         # creating an empty list
    
    for n in nums:
        result.append(n * n)
    
    return result

numbers = [1, 2, 3, 4]
print(square_list(numbers))

# %% [markdown]
# ## F. Tuple Parameters and Return Values
# ### Example 1: Access Tuple Elements

# %%
def first_item(data): 
    return data[0] 

print(first_item((100, 200, 300)))
# Out:
# 100

# %% [markdown]
# ### Example 2: Return Multiple Values

# %%
def student(): 
    return ("Ali", 21, "CS") 

print(student())
# Out:
# ('Ali', 21, 'CS')

# %% [markdown]
# ## G. Dictionary Parameters and Return Values
# ### Example 1: Access Dictionary Value

# %%
def get_name(student): 
    return student["name"] 

data = {"name": "Ahmed", "age": 20} 

print(get_name(data))
# Out:
# Ahmed

# %% [markdown]
# ### Example 2: Return Dictionary

# %%
def create_student(): 
    return { "name": "Sara", "age": 22 } 

print(create_student())
# Out:
# {'name': 'Sara', 'age': 22}

# %% [markdown]
# ## H. Mixed Data Types
#
# ### Example

# %%
def student_info(name, age, cgpa): 
    return f"{name} is {age} years old and has CGPA {cgpa}" 

print(student_info("Ali", 21, 3.7))
# Out:
# Ali is 21 years old and has CGPA 3.7

# %% [markdown]
# # Function Returning Multiple Values
# Python can return multiple values separated by commas.

# %%
def calculate(a, b): 
    return a + b, a - b, a * b 

sum_val, diff_val, prod_val = calculate(10, 5) 

print(sum_val) 
print(diff_val) 
print(prod_val)
# Out:
# 15
# 5
# 50

# %% [markdown]
# # Function Without Return Statement

# %%
def show_message(): 
    print("Python Function") 

result = show_message() 
print(result)
# Out:
# Python Function
# None

# %% [markdown]
# **Explanation:**
# - Functions without `return` automatically return `None`.

# %% [markdown]
# # Comparison with C/C++
#
# | Feature | C/C++ | Python |
# | --------------------- | ------------------------------- | ------------------ |
# | Function Definition | `int add(int a,int b)` | `def add(a,b)` |
# | Data Type Declaration | Required | Not Required |
# | Return Statement | Optional (depending on type) | Optional |
# | Multiple Returns | Difficult (structures/pointers) | Directly Supported |
# | Default Parameters | Supported | Supported |
# | First-Class Functions | Limited | Fully Supported |

# %% [markdown]
# # Key Takeaways
#
# - Functions are reusable blocks of code.
# - Functions are defined using the `def` keyword.
# - Parameters receive values from the caller.
# - Arguments are actual values passed during function calls.
# - `return` sends results back to the caller.
# - Functions can work with integers, floats, strings, booleans, lists, tuples, dictionaries, and mixed data types.
# - Python functions can return multiple values.
# - Functions without `return` automatically return `None`.

# %% [markdown]
# # Practice Tasks

# %% [markdown]
# # Task 1: Factorial Calculator
#
# ### Problem
#
# Write a function named `factorial()` that accepts an integer `n` and returns the factorial of that number.
#
# The factorial of a number is calculated as:
#
# $$
# n! = n \times (n-1) \times (n-2) \times \cdots \times 1
# $$
#
# For example:
#
# ```text
# 5! = 5 × 4 × 3 × 2 × 1 = 120
# ```

# %%
# Solution
def factorial(n):
    result = 1

    for i in range(1, n + 1):
        result = result * i

    return result


print(factorial(5))
print(factorial(7))
print(factorial(0))

# %% [markdown]
# # Task 2: Computing `x` power `n`
#
# ### Problem
#
# Write a function named `power()` that accepts a number `x` and a power `n` and returns `x` raised to the power `n` (Without using built-in functions or operators.).
#
# For example:
#
# ```text
# power(3, 3) → 27
# power(5, 5) → 125
# ```
#
# ### Expected Output
#
# ```text
# 27
# 3125
# ```

# %%
def power(x, n):
    result = 1
    
    for i in range(1, n+1):
        result = result * x
    
    return result

print(power(3, 3))
print(power(-4, 5))
print(power(5, 5))

# %% [markdown]
# # Task 3: Even or Odd Checker
#
# ### Problem
#
# Write a function named `check_even_odd()` that accepts an integer and returns:
#
# - `"Even"` if the number is even.
# - `"Odd"` if the number is odd.
#
#
# ### Expected Output
#
# ```text
# Even
# Odd
# Even
# ```

# %%
def check_even_odd(number):
    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"


print(check_even_odd(10))
print(check_even_odd(7))
print(check_even_odd(24))

# %% [markdown]
# # Task 4: Find the Largest of Three Numbers
#
# ### Problem
#
# Write a function named `largest()` that accepts three numbers and returns the largest number.
#
#
# ### Example
#
# ```text
# largest(10, 25, 15) → 25
# largest(50, 20, 30) → 50
# ```

# %%
def largest(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c


print(largest(10, 25, 15))
print(largest(50, 20, 30))
print(largest(7, 7, 3))
# Out:
# 25
# 50
# 7

# %% [markdown]
# # Thanks You!
