# %% [markdown]
# # Lecture #10
# <br>
#
# **Collections**: Lists and List Operations (Lists vs C/C++ Arrays)

# %% [markdown]
# ## 1. What are Collections in Python?
#
# A **Collection** is a data structure that can store multiple values in a single variable. Python provides several collection types such as Lists, Tuples, Sets, and Dictionaries.

# %% [markdown]
# ### Key Points
#
# - Store multiple items together.
# - Reduce the need for many separate variables.
# - Allow easy manipulation of grouped data.
# - Can contain different data types.
# - Widely used in AI, Data Science, and General Programming.

# %% [markdown]
# ### Example

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# # 2. Lists in Python
#
#
# A **List** is an ordered, mutable (changeable) collection of items enclosed in square brackets `[]`.
#
# ### Characteristics of Lists
#
# - Ordered collection.
# - Mutable (can be modified).
# - Allows duplicate values.
# - Can store different data types.
# - Supports indexing and slicing.
#
# **Note:** By `Ordered collection` we mean that the elements in a list maintain a specific order, and each element has a position (index). Because **ordered** is a property of the data structure, not something unique to lists.

# %% [markdown]
# ### Example

# %%
student = ["Ali", 20, 3.8, True]
print(student)
# Out:
# ['Ali', 20, 3.8, True]

# %% [markdown]
# # 3. Creating Lists
#
# ### Empty List

# %%
my_list = []
print(my_list)
# Out:
# []

# %% [markdown]
# ### List of Integers

# %%
numbers = [1, 2, 3, 4, 5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### List of Strings

# %%
names = ["Ali", "Sara", "Ahmed"]
names
# Out:
# ['Ali', 'Sara', 'Ahmed']

# %% [markdown]
# ### Mixed Data Types

# %%
data = [10, "Python", 3.14, True]
data
# Out:
# [10, 'Python', 3.14, True]

# %% [markdown]
# # 4. Accessing List Elements
#
# Lists use **zero-based indexing**.

# %%
names = ["Ali", "Sara", "Ahmed"]

print(names[0])
print(names[1])
print(names[2])
# Out:
# Ali
# Sara
# Ahmed

# %% [markdown]
# ### Negative Indexing

# %%
names = ["Ali", "Sara", "Ahmed"]

print(names[-1])
print(names[-2])
# Out:
# Ahmed
# Sara

# %% [markdown]
# # 5. List Slicing
#
# ### Syntax
#
# ```python
# list[start:end:step]
# ```

# %% [markdown]
# ### Example

# %%
numbers = [10, 20, 30, 40, 50, 60]

print(numbers[1:4])
print(numbers[:3])
print(numbers[3:])
print(numbers[::2])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [40, 50, 60]
# [10, 30, 50]

# %% [markdown]
# ### Modifying List Elements

# %%
numbers = [10, 20, 30]

numbers[1] = 99

print(numbers)
# Out:
# [10, 99, 30]

# %% [markdown]
# # 6. Common List Operations

# %% [markdown]
# ## Length of List

# %%
numbers = [10, 20, 30, 40]

print(len(numbers))
# Out:
# 4

# %% [markdown]
# ## Concatenation

# %%
list1 = [1, 2]
list2 = [3, 4]

result = list1 + list2
print(result)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## Repetition

# %%
numbers = [1, 2]

print(numbers * 3)
# Out:
# [1, 2, 1, 2, 1, 2]

# %% [markdown]
# ## Membership Operator

# %%
numbers = [10, 20, 30]

print(20 in numbers)
print(100 in numbers)
# Out:
# True
# False

# %% [markdown]
# # 7. Important List Methods
#
# ## append()
#
# Adds an item at the end.

# %%
numbers = [10, 20, 30]

numbers.append(40)
print(numbers)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ## insert()
#
# Adds an item at a specific position.

# %%
numbers = [10, 20, 30]

numbers.insert(1, 15)
print(numbers)
# Out:
# [10, 15, 20, 30]

# %% [markdown]
# ## remove()
#
# Removes the first matching value.

# %%
numbers = [10, 20, 30, 20]

numbers.remove(20)

print(numbers)
# Out:
# [10, 30, 20]

# %% [markdown]
# ## pop()
#
# Removes an element by last index.

# %%
numbers = [10, 20, 30]
numbers.pop()
print(numbers)
# Out:
# [10, 20]

# %% [markdown]
# ## sort()
#
# Sorts the list.

# %%
numbers = [40, 10, 30, 20]
numbers.sort()
print(numbers)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ## reverse()
#
# Reverses the list.

# %%
numbers = [10, 20, 30]
numbers.reverse()
print(numbers)
# Out:
# [30, 20, 10]

# %% [markdown]
# ## clear()
#
# Removes all elements.

# %%
numbers = [10, 20, 30]
numbers.clear()
print(numbers)
# Out:
# []

# %% [markdown]
# # 8. Iterating Through Lists
#
# ## Using for Loop

# %%
numbers = [10, 20, 30, 40]
for n in numbers:
    print(n)
# Out:
# 10
# 20
# 30
# 40

# %%
numbers = [10, 20, 30, 40]
for n in numbers:
    print(n, numbers[n])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 numbers = [10, 20, 30, 40]
#       2 for n in numbers:
# ----> 3     print(n, numbers[n])
#
# IndexError: list index out of range

# %% [markdown]
# ## Using Index

# %%
numbers = [10, 20, 30]
for i in range(len(numbers)):
    print(i, numbers[i])
# Out:
# 0 10
# 1 20
# 2 30

# %% [markdown]
# # 9. Nested Lists
#
# A list can contain other lists.

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(matrix[1][2])
# Out:
# 6

# %% [markdown]
# # 10. Lists vs C/C++ Arrays
#
# | Feature | Python List | C/C++ Array |
# |---|---|---|
# | Size | Dynamic | Fixed |
# | Data Types | Mixed Allowed | Same Type Only |
# | Memory | Managed Automatically | Lower-level memory management |
# | Built-in Operations | Many Available | More Limited |
# | Resizable | Yes | No |
# | Ease of Use | Very Easy | More Complex |
# | Indexing | Yes | Yes |
# | Slicing | Supported | Not directly supported |

# %% [markdown]
# ## Example: C++ Array
#
# ```cpp
# int numbers[5] = {10, 20, 30, 40, 50};
# ```
#
# ### Limitations
#
# - Fixed size.
# - Same data type.
# - Cannot easily add or remove elements.

# %% [markdown]
# ## Equivalent Python List

# %%
numbers = [10, 20, 30, 40, 50]

numbers.append(60)

print(numbers)
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# ### Advantages
#
# - Dynamic resizing.
# - Rich built-in methods.
# - Easier syntax.
# - Can store mixed types.

# %% [markdown]
# # Summary
#
# - A **List** is an ordered and mutable collection in Python.
# - Lists support indexing, slicing, insertion, deletion, and sorting.
# - Python lists are dynamic and more flexible than C/C++ arrays.
# - Lists can store mixed data types and nested collections.
# - Common methods include `append()`, `insert()`, `remove()`, `pop()`, `sort()`, and `reverse()`.
# - Lists are among the most frequently used data structures in Python, AI, Data Science, and Software Development.

# %% [markdown]
# # Thank You!
